# %%
import numpy as np 
import pandas as pd 

diet_data = pd.read_csv('./foodDiet.csv')
diet_data
# Out:
#     Person  gender  Age  Height  pre.weight  Diet  weight6weeks
# 0       25       0   41     171          60     2          60.0
# 1       26       0   32     174         103     2         103.0
# 2        1       0   22     159          58     1          54.2
# 3        2       0   46     192          60     1          54.0
# 4        3       0   55     170          64     1          63.3
# ..     ...     ...  ...     ...         ...   ...           ...
# 73      74       1   35     183          83     3          80.2
# 74      75       1   49     177          84     3          79.9
# 75      76       1   28     164          85     3          79.7
# 76      77       1   40     167          87     3          77.8
# 77      78       1   51     175          88     3          81.9
#
# [78 rows x 7 columns]

# %%
from scipy.stats import f_oneway

f_static, p_value = f_oneway(diet_data['pre.weight'], diet_data['Diet'])

alpha = 0.05
print(p_value)

if p_value <= alpha:
    print('Reject hypothesis')
else:
    print('Fail to reject hypothesis')
# Out:
# 1.2657363747484932e-119
# Reject hypothesis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='Diet',y='pre.weight', data=diet_data)
plt.show()
